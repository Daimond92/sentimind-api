# %% [markdown]
# <a href="https://colab.research.google.com/github/Daimond92/sentimind-api/blob/feature%2Fds-model-training-MariaC/ds/notebooks/inicial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Prueba de subida

# %% [markdown]
# ## Segundo test
